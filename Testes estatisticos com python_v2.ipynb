# %%
import pandas as pd

tmdb = pd.read_csv('tmdb_5000_movies.csv')
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import seaborn as sns

ax = sns.distplot(tmdb.vote_average)
ax.set(xlabel  = 'nota média', ylabel = 'densidade')
ax.set_title('média de votos em filmes no TMDB 5000')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\2942822175.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.vote_average)
# Text(0.5, 1.0, 'média de votos em filmes no TMDB 5000')

# %%
import seaborn as sns

ax = sns.distplot(tmdb.vote_average, norm_hist = False, kde = False)
ax.set(xlabel  = 'nota média', ylabel = 'frequência')
ax.set_title('média de votos em filmes no TMDB 5000')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\2627992511.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.vote_average, norm_hist = False, kde = False)
# Text(0.5, 1.0, 'média de votos em filmes no TMDB 5000')

# %%
ax = sns.boxplot(x = tmdb.vote_average)
ax.set_title(' Distribuição de nota média dos filmes do TMDB 5000')
ax.set(xlabel = 'nota média do filme ')
# Out:
# [Text(0.5, 0, 'nota média do filme ')]

# %% [markdown]
# tem algo de estranho com meus dados... não faz sentido filmes cuja nota média seja 0 ou 10 ... vamos ver?

# %%
tmdb.query('vote_average == 0').head()
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# 3852                            NaN  395766
# 3855    http://www.timetochoose.com  370662
#
#                                                keywords original_language  \
# 1464                                                 []                en
# 3669                                                 []                en
# 3670                                                 []                en
# ...

# %%
tmdb_com_mais_De_10_votos = tmdb.query('vote_count >= 10')
tmdb_com_mais_De_10_votos.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %% [markdown]
# detectamos que alguns filmes tiveram poucos votos ou até mesmo nenhum voto. Decidimos que esses filmes não devem pertencer a nossa análise

# %%
ax = sns.distplot(tmdb_com_mais_De_10_votos.vote_average, norm_hist = False, kde = False)
ax.set(xlabel  = 'nota média', ylabel = 'frequência')
ax.set_title('média de votos em filmes no TMDB 5000 dentre os filmes com 10 ou mais votos')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\2413284621.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_De_10_votos.vote_average, norm_hist = False, kde = False)
# Text(0.5, 1.0, 'média de votos em filmes no TMDB 5000 dentre os filmes com 10 ou mais votos')

# %%
ax = sns.distplot(tmdb_com_mais_De_10_votos.vote_average, norm_hist = False)
ax.set(xlabel  = 'nota média', ylabel = 'densidade')
ax.set_title('média de votos em filmes no TMDB 5000 dentre os filmes com 10 ou mais votos')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\417809343.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_De_10_votos.vote_average, norm_hist = False)
# Text(0.5, 1.0, 'média de votos em filmes no TMDB 5000 dentre os filmes com 10 ou mais votos')

# %%
ax = sns.boxplot(x = tmdb_com_mais_De_10_votos.vote_average)
ax.set_title(' Distribuição de nota média dos filmes do TMDB 5000 dentre os filmes com 10 ou mais votos')
ax.set(xlabel = 'nota média do filme ')
# Out:
# [Text(0.5, 0, 'nota média do filme ')]

# %% [markdown]
# # Analisaremos também o movielens

# %%
notas = pd.read_csv('ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_media_por_filme=notas.groupby('movieId').mean()['rating']
nota_media_por_filme.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
ax = sns.distplot(nota_media_por_filme.values)
ax.set(xlabel  = 'nota média', ylabel = 'densidade')
ax.set_title('média de votos em filmes no MovieLens 100k')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\4206771869.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_por_filme.values)
# Text(0.5, 1.0, 'média de votos em filmes no MovieLens 100k')

# %%
quantidade_de_vots_por_filme=notas.groupby('movieId').count()
filmes_com_pelo_menos_10_votos = quantidade_de_vots_por_filme.query('rating >= 10').index
filmes_com_pelo_menos_10_votos
# Out:
# Index([     1,      2,      3,      5,      6,      7,      9,     10,     11,
#            12,
#        ...
#        166461, 166528, 166643, 168250, 168252, 174055, 176371, 177765, 179819,
#        187593],
#       dtype='int64', name='movieId', length=2269)

# %%
nota_media_dos_filmes_com_pelo_menos_10_votos = nota_media_por_filme.loc[filmes_com_pelo_menos_10_votos.values]

# %%
nota_media_dos_filmes_com_pelo_menos_10_votos
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 5         3.071429
# 6         3.946078
#             ...
# 174055    3.423077
# 176371    3.805556
# 177765    3.538462
# 179819    3.125000
# 187593    3.875000
# Name: rating, Length: 2269, dtype: float64

# %%
ax = sns.distplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values)
ax.set(xlabel  = 'nota média', ylabel = 'densidade')
ax.set_title('média de votos em filmes no MovieLens 100k')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\2925213156.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values)
# Text(0.5, 1.0, 'média de votos em filmes no MovieLens 100k')

# %%
ax = sns.boxplot(x = nota_media_dos_filmes_com_pelo_menos_10_votos.values)
ax.set_title(' Distribuição de nota média dos filmes do MovieLens 100k')
ax.set(xlabel = 'nota média do filme ')
# Out:
# [Text(0.5, 0, 'nota média do filme ')]

# %%
ax = sns.distplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values, 
                  hist_kws={'cumulative':True},
                  kde_kws= {'cumulative':True})
ax.set(xlabel  = 'nota média', ylabel = '% acumulada de filmes')
ax.set_title('média de votos em filmes no MovieLens 100k')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\616268665.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values,
# Text(0.5, 1.0, 'média de votos em filmes no MovieLens 100k')

# %%
ax = sns.distplot(tmdb_com_mais_De_10_votos.vote_average, 
                  hist_kws={'cumulative':True},
                  kde_kws= {'cumulative':True})
ax.set(xlabel  = 'nota média', ylabel = '% acumulada de filmes')
ax.set_title('média de votos em filmes no TMDB 5K')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\3859576583.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_De_10_votos.vote_average,
# Text(0.5, 1.0, 'média de votos em filmes no TMDB 5K')

# %% [markdown]
# # Analisando a distribuição de dados capturados de outros campos do TMDB

# %%
tmdb_com_mais_De_10_votos.vote_count
# Out:
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124
#         ...
# 4790       17
# 4792       63
# 4796      658
# 4798      238
# 4802       16
# Name: vote_count, Length: 4392, dtype: int64

# %%
ax = sns.distplot(tmdb_com_mais_De_10_votos.vote_count)
ax.set(xlabel  = 'numero de votos', ylabel = 'densidade')
ax.set_title('numero de votos em filmes no TMDB 5K com 10 ou mais votos')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\581097116.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_De_10_votos.vote_count)
# Text(0.5, 1.0, 'numero de votos em filmes no TMDB 5K com 10 ou mais votos')

# %%
bdgt =tmdb.query('budget > 0').budget

# %%
ax = sns.distplot(bdgt)
ax.set(xlabel  = 'budget (gastos)', ylabel = 'densidade')
ax.set_title('gastos em filmes no TMDB 5K')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\3454926793.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(bdgt)
# Text(0.5, 1.0, 'gastos em filmes no TMDB 5K')

# %%
tmdb.query('popularity == 0')
# Out:
#       budget genres homepage      id keywords original_language  \
# 4553       0     []      NaN  380097       []                en
#
#                   original_title  \
# 4553  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      production_companies production_countries release_date  revenue  runtime  \
# 4553                   []                   []          NaN        0      0.0
#
#      spoken_languages    status tagline                       title  \
# 4553               []  Released     NaN  America Is Still the Place
#
#       vote_average  vote_count
# 4553           0.0           0

# %%
ax = sns.distplot(tmdb.popularity)
ax.set(xlabel  = 'popularidade', ylabel = 'densidade')
ax.set_title('popularidade em filmes no TMDB 5K')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\3665347142.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.popularity)
# Text(0.5, 1.0, 'popularidade em filmes no TMDB 5K')

# %%
ax = sns.distplot(tmdb.runtime)
ax.set(xlabel  = 'tempo de duração', ylabel = 'densidade')
ax.set_title('tempo de duração em filmes no TMDB 5K')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\1689841179.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.runtime)
# Text(0.5, 1.0, 'tempo de duração em filmes no TMDB 5K')

# %%
tmdb.runtime.isnull().sum()
# Out:
# 2

# %%
tmdb.runtime.dropna()
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4801, dtype: float64

# %%
ax = sns.distplot(tmdb.query('runtime > 0').runtime.dropna())
ax.set(xlabel  = 'tempo de duração', ylabel = 'densidade')
ax.set_title('tempo de duração em filmes no TMDB 5K')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\2567543326.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query('runtime > 0').runtime.dropna())
# Text(0.5, 1.0, 'tempo de duração em filmes no TMDB 5K')

# %%
ax = sns.distplot(tmdb.query('runtime > 0').runtime.dropna(), 
                  hist_kws={'cumulative':True},
                  kde_kws= {'cumulative':True})
ax.set(xlabel  = 'Tempo de duração', ylabel = '% acumulada de filmes')
ax.set_title('Tepo de duração em filmes no TMDB 5K')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\99069510.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query('runtime > 0').runtime.dropna(),
# Text(0.5, 1.0, 'Tepo de duração em filmes no TMDB 5K')

# %%
tmdb.query('runtime>0').runtime.dropna().quantile(0.8)
#quantile mostra qual é o tempo de 80% desses filmes
# Out:
# 121.0

# %%
import numpy as np
import matplotlib.pyplot as plt 
np.random.seed(75243)

temp = nota_media_dos_filmes_com_pelo_menos_10_votos.sample(frac=1)

medias = list()

medias = [temp[0:i].mean() for i in range (1, len(temp))]

plt.plot(medias)

# %%
from statsmodels.stats.weightstats import zconfint

zconfint(nota_media_dos_filmes_com_pelo_menos_10_votos)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
from statsmodels.stats.weightstats import DescrStatsW

descr_todos_com_10_votos = DescrStatsW(nota_media_dos_filmes_com_pelo_menos_10_votos)
descr_todos_com_10_votos.tconfint_mean()
# Out:
# (3.411234839229381, 3.4528658418411395)

# %% [markdown]
# # Vamos ver o filme 1...

# %%
filmes = pd.read_csv('movies.csv')
filmes.query('movieId == 1')
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
notas1 = notas.query('movieId ==1')
notas1
# Out:
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 516         5        1     4.0   847434962
# 874         7        1     4.5  1106635946
# 1434       15        1     2.5  1510577970
# 1667       17        1     4.5  1305696483
# ...       ...      ...     ...         ...
# 97364     606        1     2.5  1349082950
# 98479     607        1     4.0   964744033
# 98666     608        1     2.5  1117408267
# 99497     609        1     3.0   847221025
# 99534     610        1     5.0  1479542900
#
# [215 rows x 4 columns]

# %%
ax = sns.distplot(notas1.rating)
ax.set(xlabel  = 'nota', ylabel = 'densidade')
ax.set_title('Distribuição das notas do filme Toy Story')
# Out:
# C:\Users\volke\AppData\Local\Temp\ipykernel_4840\1636037770.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(notas1.rating)
# Text(0.5, 1.0, 'Distribuição das notas do filme Toy Story')

# %%
ax = sns.boxplot(x = notas1.rating)
ax.set(xlabel  = 'nota')
ax.set_title('Distribuição das notas do filme Toy Story')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas do filme Toy Story')

# %%
notas1.rating.mean()
# Out:
# 3.9209302325581397

# %%
notas1.rating.count()
# Out:
# 215

# %%
zconfint(notas1.rating)
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
nota_media_dos_filmes_com_pelo_menos_10_votos.mean()
# Out:
# 3.4320503405352594

# %%
from statsmodels.stats.weightstats import ztest

ztest(notas1.rating, value = 3.4320503405352594 )
# Out:
# (8.586342305916732, 8.97819040188565e-18)

# %%
np.random.seed(75241)

temp = notas1.sample(frac=1).rating

def calcula_teste(i):
    media = temp[0:i].mean()
    stat, p = ztest(temp[0:i], value = 3.4320503405352594)
    return (i, media, p)

valores = np.array([calcula_teste(i) for i in range (1, len(temp))])


plt.plot(valores[:,0],valores[:,1])    
plt.plot(valores[:,0],valores[:,2])
plt.hlines( y = 0.05, xmin =2, xmax = len(temp), colors='r')
# Out:
# c:\Users\volke\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\weightstats.py:1556: RuntimeWarning: invalid value encountered in scalar divide
#   var_pooled = x1_var / (nobs1 - ddof)

# %%
print(ztest(notas1.rating, notas.rating))
zconfint(notas1.rating, notas.rating)
# Out:
# (5.894327101501841, 3.762112778881965e-09)
# (0.2799245129192442, 0.5588219849631111)

# %%
from scipy.stats   import ttest_ind

ttest_ind(notas.rating, notas1.rating)
# Out:
# TtestResult(statistic=-5.894327101501841, pvalue=3.774003138720876e-09, df=101049.0)

# %%
descr_todas_as_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1.rating)
comparacao = descr_todas_as_notas.get_compare(descr_toystory)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
pip install -U statsmodels
# Out:
# ...
#   Obtaining dependency information for statsmodels from https://files.pythonhosted.org/packages/6d/c8/46d355b3c2d04881ce745c667eba6b08ea2215a1ccae875c64b725c3d348/statsmodels-0.14.1-cp310-cp310-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for patsy>=0.5.4 from https://files.pythonhosted.org/packages/43/f3/1d311a09c34f14f5973bb0bb0dc3a6e007e1eda90b5492d082689936ca51/patsy-0.5.6-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB 1.4 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/9.8 MB 1.3 MB/s eta 0:00:08
#     --------------------------------------- 0.2/9.8 MB 1.3 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/9.8 MB 1.7 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/9.8 MB 2.2 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.8 MB 3.2 MB/s eta 0:00:03
# ...
